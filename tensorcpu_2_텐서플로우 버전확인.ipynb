# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /Users/dahlmoon/anaconda3
# python8                  /Users/dahlmoon/anaconda3/envs/python8

# %% [markdown]
# ## 버전 차이있을 때 처리하기
#
#      conda install -c conda-forge tensorflow  # to install
#
#     conda upgrade -c conda-forge tensorflow  # to upgrade

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.4.1'

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            0.11.0
# aiohttp                            3.6.2
# alabaster                          0.7.12
# alembic                            1.4.2
# anaconda-client                    1.7.2
# anaconda-navigator                 1.10.0
# anaconda-project                   0.9.1
# AnyQt                              0.0.10
# appdirs                            1.4.4
# applaunchservices                  0.2.1
# appnope                            0.1.2
# appscript                          1.1.2
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astor                              0.8.0
# astroid                            2.4.2
# astropy                            4.2
# astunparse                         1.6.3
# async-generator                    1.10
# async-timeout                      3.0.1
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autograd                           1.3
# autograd-gamma                     0.4.2
# autopep8                           1.5.4
# azure-core                         1.7.0
# azure-storage-blob                 12.3.2
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# baycomp                            1.0.2
# bayesian-optimization              1.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.6.3
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.0
# blis                               0.4.1
# bokeh                              2.2.3
# boto                               2.49.0
# boto3                              1.14.34
# botocore                           1.17.34
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# CacheControl                       0.12.6
# cachetools                         4.1.0
# catalogue                          1.0.0
# catboost                           0.23.2
# certifi                            2020.12.5
# cffi                               1.14.4
# chardet                            4.0.0
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# CoDrone                            1.2.4
# colorama                           0.4.4
# colorlover                         0.3.0
# combo                              0.1.1
# commonmark                         0.9.1
# conda                              4.9.2
# conda-build                        3.21.4
# conda-package-handling             1.7.2
# conda-verify                       3.4.2
# confuse                            1.3.0
# contextlib2                        0.6.0.post1
# coverage                           5.2.1
# cryptography                       3.3.1
# cufflinks                          0.17.3
# cycler                             0.10.0
# cymem                              2.0.3
# cypari                             2.4.0
# Cython                             0.29.21
# cytoolz                            0.11.0
# dabl                               0.1.8
# dask                               2021.2.0
# dask-glm                           0.2.0
# dask-ml                            1.6.0
# dask-xgboost                       0.1.10
# databricks                         0.2
# databricks-cli                     0.11.0
# datashape                          0.5.2
# datefinder                         0.7.1
# DateTime                           4.3
# decorator                          4.4.2
# defusedxml                         0.6.0
# dictdiffer                         0.8.1
# diff-match-patch                   20200713
# dill                               0.3.3
# distributed                        2021.1.1
# Django                             2.2.6
# django-extensions                  2.2.5
# docker                             4.2.2
# docopt                             0.6.2
# docutils                           0.15.2
# e-drone                            0.1.31
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# Faker                              4.1.2
# fast-histogram                     0.9
# fastcache                          1.1.0
# fastcluster                        1.1.26
# filelock                           3.0.12
# finance-datareader                 0.9.20
# findspark                          1.4.2
# flake8                             3.8.4
# Flask                              1.1.2
# flatbuffers                        1.12
# fsspec                             0.8.3
# funcy                              1.14
# future                             0.18.2
# FXrays                             1.3.3
# gast                               0.3.3
# gensim                             3.8.3
# gevent                             21.1.1
# gitdb                              4.0.5
# GitPython                          3.1.7
# glob2                              0.7
# glue-core                          0.15.6
# glue-vispy-viewers                 0.12.2
# glueviz                            1.0.0
# gmpy2                              2.0.8
# google                             3.0.0
# google-auth                        1.16.0
# google-auth-oauthlib               0.4.1
# google-pasta                       0.2.0
# googletrans                        3.0.0
# gorilla                            0.3.0
# graphviz                           0.14.2
# greenlet                           1.0.0
# grpcio                             1.32.0
# gunicorn                           20.0.4
# h11                                0.9.0
# h2                                 3.2.0
# h5py                               2.10.0
# hdfs                               2.5.8
# hdfs3                              0.3.1
# HeapDict                           1.0.1
# hpack                              3.0.0
# hstspreload                        2020.7.22
# html5lib                           1.1
# htmlmin                            0.1.12
# httpcore                           0.9.1
# httpx                              0.13.3
# hyperframe                         5.2.0
# hyperopt                           0.1.2
# idna                               2.10
# imagecodecs                        2021.1.11
# ImageHash                          4.1.0
# imageio                            2.9.0
# imagesize                          1.2.0
# imbalanced-learn                   0.7.0
# importlib-metadata                 2.0.0
# importlib-resources                3.0.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.20.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isodate                            0.6.0
# isort                              5.7.0
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             2.11.3
# jmespath                           0.10.0
# joblib                             1.0.0
# JPype1                             0.7.0
# json-tricks                        3.15.2
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.7
# jupyter-console                    6.2.0
# jupyter-core                       4.7.1
# jupyterlab                         2.2.6
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  1.2.0
# jupyterlab-widgets                 1.0.0
# Keras                              2.3.1
# Keras-Applications                 1.0.8
# Keras-Preprocessing                1.1.2
# keyring                            22.0.1
# keyrings.alt                       3.4.0
# kiwisolver                         1.3.1
# kmodes                             0.10.2
# koalas                             1.6.0
# konlpy                             0.5.1
# korean-lunar-calendar              0.2.0
# lazy-object-proxy                  1.4.3
# libarchive-c                       2.9
# lifelines                          0.24.12
# lightgbm                           2.3.1
# llvmlite                           0.34.0
# locket                             0.2.1
# lockfile                           0.12.2
# lxml                               4.6.2
# Mako                               1.1.3
# Markdown                           3.1.1
# MarkupSafe                         1.1.1
# matplotlib                         3.2.2
# mccabe                             0.6.1
# mecab-python                       0.996-ko-0.9.2
# missingno                          0.4.2
# mistune                            0.8.4
# mkl-fft                            1.2.0
# mkl-random                         1.1.1
# mkl-service                        2.3.0
# mlflow                             1.10.0
# mlxtend                            0.17.3
# mock                               4.0.3
# modin                              0.8.3
# more-itertools                     8.6.0
# mpl-scatter-density                0.7
# mpmath                             1.1.0
# msgpack                            1.0.2
# msrest                             0.6.18
# multidict                          4.7.6
# multipledispatch                   0.6.0
# murmurhash                         1.0.2
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclient                           0.5.1
# nbconvert                          6.0.7
# nbformat                           5.1.2
# nest-asyncio                       1.4.3
# netifaces                          0.10.9
# networkx                           2.5
# ngboost                            0.2.0
# nltk                               3.5
# nose                               1.3.7
# notebook                           6.2.0
# numba                              0.51.2
# numexpr                            2.7.2
# numpy                              1.20.1
# numpydoc                           1.1.0
# oauthlib                           3.1.0
# odo                                0.5.0
# olefile                            0.46
# opencv-contrib-python              4.1.1.26
# openpyxl                           3.0.6
# openTSNE                           0.4.4
# opt-einsum                         3.3.0
# orange-canvas-core                 0.1.15
# orange-widget-base                 4.7.0
# Orange3                            3.26.0
# packaging                          20.9
# pandas                             1.1.5
# pandas-profiling                   2.8.0
# pandasql                           0.7.3
# pandocfilters                      1.4.3
# parquet                            1.3.1
# parso                              0.7.0
# partd                              1.1.0
# path                               15.1.0
# pathlib2                           2.3.5
# pathspec                           0.7.0
# pathtools                          0.1.2
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# phik                               0.10.0
# pickle5                            0.0.11
# pickleshare                        0.7.5
# Pillow                             8.1.0
# pip                                20.3.3
# pkginfo                            1.7.0
# plac                               1.1.3
# plink                              2.3.1
# plotly                             4.14.3
# pluggy                             0.13.1
# ply                                3.11
# preshed                            3.0.2
# prettytable                        0.7.2
# prometheus-client                  0.9.0
# prometheus-flask-exporter          0.15.4
# prompt-toolkit                     3.0.8
# protobuf                           3.10.0
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# py-spy                             0.3.3
# py4j                               0.10.9
# pyaml                              20.4.0
# pyarrow                            3.0.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycaret                            2.2.3
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycrypto                           2.6.1
# pycurl                             7.43.0.6
# pydocstyle                         5.1.1
# pydot                              1.4.1
# pyecharts                          1.5.1
# pyerfa                             1.7.1.1
# pyflakes                           2.2.0
# pygame                             1.9.6
# Pygments                           2.7.4
# PyHive                             0.6.2
# pyLDAvis                           2.1.2
# pylint                             2.6.0
# pyls-black                         0.4.6
# pyls-spyder                        0.3.0
# pymongo                            3.11.0
# pyod                               0.8.1
# pyodbc                             4.0.0-unsupported
# PyOpenGL                           3.1.1a1
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pypng                              0.0.20
# pyqtgraph                          0.11.0
# pyrsistent                         0.17.3
# pyserial                           3.4
# PySocks                            1.7.1
# pyspark                            3.0.1
# pysqldf                            1.2.3
# pytest                             6.2.2
# python-dateutil                    2.8.1
# python-editor                      1.0.4
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# python-louvain                     0.14
# python-snappy                      0.5.4
# PythonWebHDFS                      0.2.3
# pytz                               2021.1
# PyWavelets                         1.1.1
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.1
# qtconsole                          5.0.2
# QtPy                               1.9.0
# querystring-parser                 1.2.4
# ray                                0.8.6
# redis                              3.4.1
# regex                              2020.11.13
# requests                           2.25.1
# requests-file                      1.5.1
# requests-oauthlib                  1.3.0
# retrying                           1.3.3
# rfc3986                            1.4.0
# rope                               0.18.0
# rsa                                4.0
# Rtree                              0.9.4
# ruamel-yaml                        0.15.87
# ruamel.yaml                        0.16.10
# ruamel.yaml.clib                   0.2.0
# s3transfer                         0.3.3
# sasl                               0.2.1
# schema                             0.7.2
# scikit-image                       0.17.2
# scikit-learn                       0.24.1
# scikit-opt                         0.5.7
# scikit-optimize                    0.7.4
# scikit-plot                        0.3.7
# scikit-surprise                    1.1.1
# scipy                              1.6.0
# seaborn                            0.11.1
# Send2Trash                         1.5.0
# serverfiles                        0.3.0
# setuptools                         52.0.0.post20210125
# shap                               0.35.0
# simplegeneric                      0.8.1
# simplejson                         3.16.0
# singledispatch                     3.4.0.3
# six                                1.15.0
# smart-open                         2.1.0
# smmap                              3.0.4
# snappy-manifolds                   1.1.1
# sniffio                            1.1.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.1
# spacy                              2.3.2
# spherogram                         1.8.3
# Sphinx                             3.4.3
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.1
# spyder-kernels                     1.10.1
# SQLAlchemy                         1.3.13
# sqlparse                           0.3.0
# srsly                              1.0.2
# statsmodels                        0.12.1
# suod                               0.0.4
# sweetviz                           1.0b6
# sympy                              1.7.1
# tables                             3.6.1
# tabulate                           0.8.7
# tangled-up-in-unicode              0.0.6
# tblib                              1.7.0
# tensor-sensor                      0.1b5
# tensorboard                        2.4.0
# tensorboard-plugin-wit             1.6.0.post3
# tensorflow                         2.4.1
# tensorflow-estimator               2.4.0
# termcolor                          1.1.0
# terminado                          0.9.2
# testpath                           0.4.4
# text-unidecode                     1.3
# textblob                           0.15.3
# textdistance                       4.2.1
# thinc                              7.4.1
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# thrift                             0.13.0
# thrift-sasl                        0.3.0
# thriftpy2                          0.4.11
# tifffile                           2021.1.14
# toml                               0.10.1
# toolz                              0.11.1
# torch                              1.2.0
# torch-vision                       0.1.6.dev0
# torchtext                          0.4.0
# tornado                            6.1
# tqdm                               4.56.0
# traitlets                          5.0.5
# tslib                              1.7
# typed-ast                          1.4.2
# typing-extensions                  3.7.4.3
# ujson                              4.0.2
# umap-learn                         0.4.6
# unicodecsv                         0.14.1
# unique-id                          1.0.1
# urllib3                            1.25.11
# vincent                            0.4.4
# visions                            0.4.4
# wasabi                             0.7.1
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webencodings                       0.5.1
# websocket-client                   0.57.0
# websockets                         8.1
# Werkzeug                           1.0.1
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# wordcloud                          1.7.0
# wrapt                              1.12.1
# wurlitzer                          2.0.1
# xgboost                            1.3.3
# xlrd                               2.0.1
# XlsxWriter                         1.3.7
# xlwings                            0.22.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.30.0
# yarl                               1.5.0
# yellowbrick                        1.1
# zict                               2.0.0
# zipp                               3.4.0
# zope.event                         4.5.0
# zope.interface                     5.2.0

# %%
count = 0
for i in dir(tf) :
    if not i.startswith("_") :
        print(i, end=", ")
        count += 1
        
        if count % 5 == 0 :
            print()
# Out:
# AggregationMethod, Assert, CriticalSection, DType, DeviceSpec,
# GradientTape, Graph, IndexedSlices, IndexedSlicesSpec, Module,
# Operation, OptionalSpec, RaggedTensor, RaggedTensorSpec, RegisterGradient,
# SparseTensor, SparseTensorSpec, Tensor, TensorArray, TensorArraySpec,
# TensorShape, TensorSpec, TypeSpec, UnconnectedGradients, Variable,
# VariableAggregation, VariableSynchronization, abs, acos, acosh,
# add, add_n, argmax, argmin, argsort,
# as_dtype, as_string, asin, asinh, assert_equal,
# assert_greater, assert_less, assert_rank, atan, atan2,
# atanh, audio, autodiff, autograph, batch_to_space,
# bfloat16, bitcast, bitwise, bool, boolean_mask,
# broadcast_dynamic_shape, broadcast_static_shape, broadcast_to, case, cast,
# clip_by_global_norm, clip_by_norm, clip_by_value, compat, complex,
# complex128, complex64, concat, cond, config,
# constant, constant_initializer, control_dependencies, convert_to_tensor, cos,
# cosh, cumsum, custom_gradient, data, debugging,
# device, distribute, divide, double, dtypes,
# dynamic_partition, dynamic_stitch, edit_distance, eig, eigvals,
# einsum, ensure_shape, equal, errors, estimator,
# executing_eagerly, exp, expand_dims, experimental, extract_volume_patches,
# eye, feature_column, fill, fingerprint, float16,
# float32, float64, floor, foldl, foldr,
# function, gather, gather_nd, get_logger, get_static_value,
# grad_pass_through, gradients, graph_util, greater, greater_equal,
# group, guarantee_const, half, hessians, histogram_fixed_width,
# histogram_fixed_width_bins, identity, identity_n, image, import_graph_def,
# init_scope, initializers, inside_function, int16, int32,
# int64, int8, io, is_tensor, keras,
# less, less_equal, linalg, linspace, lite,
# load_library, load_op_library, logical_and, logical_not, logical_or,
# lookup, losses, make_ndarray, make_tensor_proto, map_fn,
# math, matmul, matrix_square_root, maximum, meshgrid,
# metrics, minimum, mixed_precision, mlir, multiply,
# name_scope, negative, nest, newaxis, nn,
# no_gradient, no_op, nondifferentiable_batch_function, norm, not_equal,
# numpy_function, one_hot, ones, ones_initializer, ones_like,
# optimizers, pad, parallel_stack, pow, print,
# profiler, py_function, qint16, qint32, qint8,
# quantization, quantize_and_dequantize_v4, queue, quint16, quint8,
# ragged, random, random_normal_initializer, random_uniform_initializer, range,
# rank, raw_ops, realdiv, recompute_grad, reduce_all,
# reduce_any, reduce_logsumexp, reduce_max, reduce_mean, reduce_min,
# reduce_prod, reduce_sum, register_tensor_conversion_function, repeat, required_space_to_batch_paddings,
# reshape, resource, reverse, reverse_sequence, roll,
# round, saturate_cast, saved_model, scalar_mul, scan,
# scatter_nd, searchsorted, sequence_mask, sets, shape,
# shape_n, sigmoid, sign, signal, sin,
# sinh, size, slice, sort, space_to_batch,
# space_to_batch_nd, sparse, split, sqrt, square,
# squeeze, stack, stop_gradient, strided_slice, string,
# strings, subtract, summary, switch_case, sysconfig,
# tan, tanh, tensor_scatter_nd_add, tensor_scatter_nd_max, tensor_scatter_nd_min,
# tensor_scatter_nd_sub, tensor_scatter_nd_update, tensordot, test, tile,
# timestamp, tools, tpu, train, transpose,
# truediv, truncatediv, truncatemod, tuple, type_spec_from_value,
# types, uint16, uint32, uint64, uint8,
# unique, unique_with_counts, unravel_index, unstack, variable_creator_scope,
# variant, vectorized_map, version, where, while_loop,
# xla, zeros, zeros_initializer, zeros_like,

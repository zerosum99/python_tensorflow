# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.13.1'

# %%
x_data = [1,2,3]

# %%
y_data = [1,2,3]

# %%
W = tf.Variable(tf.random_uniform((1,),-1.0, 1.0))

# %%
b = tf.Variable(tf.random_uniform((1,),-1.0,1.0))

# %%
X = tf.placeholder(tf.float32, name="X")

# %%
Y = tf.placeholder(tf.float32, name="Y")

# %%
hypothesis = W * X + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.1)

# %%
train_op = optimizer.minimize(cost)

# %%
with tf.Session() as sess :
    sess.run(tf.global_variables_initializer())
    
    for step in range(100) :
        _, cost_val = sess.run([train_op, cost], feed_dict= {X: x_data, Y: y_data})
        
        print(step, cost_val, sess.run(W), sess.run(b))
        
        
    print(" test ")
    print(sess.run(hypothesis,feed_dict= {X : 5}))
# Out:
# 0 17.42946 [1.0669962] [0.32872957]
# 1 0.21710403 [0.8729745] [0.23618516]
# 2 0.011076168 [0.89705753] [0.23975831]
# 3 0.00821217 [0.89723384] [0.23298365]
# 4 0.007794177 [0.8999555] [0.22749339]
# 5 0.0074236062 [0.902333] [0.22201252]
# 6 0.0070709717 [0.9046839] [0.2166768]
# 7 0.0067350934 [0.90697485] [0.21146789]
# 8 0.0064151683 [0.90921116] [0.20638436]
# 9 0.00611045 [0.91139364] [0.20142302]
# 10 0.0058202012 [0.91352373] [0.19658096]
# 11 0.0055437325 [0.9156025] [0.19185528]
# 12 0.0052804016 [0.9176314] [0.18724322]
# 13 0.005029579 [0.91961145] [0.18274203]
# 14 0.0047906665 [0.9215439] [0.17834903]
# 15 0.0045631137 [0.92342997] [0.17406166]
# 16 0.0043463567 [0.9252706] [0.16987732]
# 17 0.0041399063 [0.9270671] [0.1657936]
# 18 0.003943251 [0.9288204] [0.16180803]
# 19 0.0037559469 [0.9305315] [0.15791827]
# 20 0.003577535 [0.9322015] [0.15412202]
# 21 0.0034075936 [0.9338312] [0.150417]
# 22 0.0032457344 [0.93542194] [0.1468011]
# 23 0.0030915653 [0.9369744] [0.14327212]
# 24 0.002944716 [0.93848944] [0.13982794]
# 25 0.002804836 [0.9399681] [0.13646656]
# 26 0.0026716013 [0.94141126] [0.13318601]
# 27 0.0025446971 [0.94281965] [0.1299843]
# 28 0.0024238217 [0.94419426] [0.12685958]
# 29 0.0023086919 [0.9455358] [0.12380996]
# 30 0.0021990214 [0.946845] [0.12083364]
# 31 0.0020945752 [0.9481229] [0.11792891]
# 32 0.0019950776 [0.94936997] [0.11509397]
# 33 0.0019003119 [0.95058703] [0.11232717]
# 34 0.0018100474 [0.95177495] [0.10962693]
# 35 0.0017240657 [0.9529342] [0.10699157]
# 36 0.0016421756 [0.9540657] [0.10441957]
# 37 0.0015641717 [0.9551699] [0.10190941]
# 38 0.001489868 [0.95624757] [0.09945956]
# 39 0.0014190959 [0.9572993] [0.09706861]
# 40 0.0013516909 [0.95832586] [0.09473517]
# 41 0.0012874833 [0.95932764] [0.09245779]
# 42 0.0012263312 [0.9603054] [0.09023517]
# 43 0.0011680756 [0.9612596] [0.08806599]
# 44 0.0011125904 [0.96219087] [0.08594894]
# 45 0.0010597432 [0.96309984] [0.0838828]
# 46 0.0010094066 [0.9639869] [0.08186631]
# 47 0.00096145604 [0.96485263] [0.07989831]
# 48 0.0009157844 [0.9656975] [0.07797759]
# 49 0.000872284 [0.9665221] [0.07610305]
# 50 0.000830856 [0.96732694] [0.07427362]
# 51 0.000791387 [0.96811235] [0.07248811]
# 52 0.0007537957 [0.9688789] [0.07074556]
# 53 0.0007179905 [0.9696271] [0.0690449]
# 54 0.00068388577 [0.9703572] [0.06738509]
# 55 0.0006513977 [0.97106975] [0.06576519]
# 56 0.0006204592 [0.9717653] [0.06418425]
# 57 0.0005909836 [0.972444] [0.0626413]
# 58 0.0005629125 [0.9731064] [0.06113544]
# 59 0.0005361725 [0.9737529] [0.05966579]
# 60 0.00051070616 [0.9743839] [0.05823148]
# 61 0.00048644535 [0.9749996] [0.05683161]
# 62 0.0004633423 [0.97560066] [0.05546544]
# 63 0.0004413301 [0.9761872] [0.0541321]
# 64 0.00042036825 [0.9767597] [0.0528308]
# 65 0.00040040058 [0.97731835] [0.05156079]
# 66 0.00038137924 [0.97786355] [0.05032128]
# 67 0.00036326525 [0.9783957] [0.04911159]
# 68 0.0003460093 [0.9789151] [0.04793099]
# 69 0.0003295742 [0.979422] [0.04677877]
# 70 0.00031392064 [0.9799167] [0.04565425]
# 71 0.00029900632 [0.98039937] [0.0445567]
# 72 0.00028480496 [0.98087066] [0.04348562]
# 73 0.00027127468 [0.9813305] [0.04244024]
# 74 0.00025838957 [0.9817793] [0.04141999]
# 75 0.0002461175 [0.9822173] [0.04042427]
# 76 0.00023442379 [0.98264474] [0.03945249]
# 77 0.00022328952 [0.98306197] [0.0385041]
# 78 0.00021268282 [0.9834692] [0.0375785]
# 79 0.0002025807 [0.9838666] [0.03667513]
# 80 0.00019295793 [0.98425436] [0.03579347]
# 81 0.00018379133 [0.9846329] [0.03493302]
# 82 0.00017506182 [0.98500234] [0.03409326]
# 83 0.00016674602 [0.9853629] [0.03327368]
# 84 0.00015882666 [0.98571473] [0.03247379]
# 85 0.00015127995 [0.9860581] [0.03169315]
# 86 0.00014409541 [0.9863933] [0.03093127]
# 87 0.00013725116 [0.9867204] [0.0301877]
# 88 0.00013073116 [0.9870396] [0.02946201]
# 89 0.00012452072 [0.9873511] [0.02875375]
# 90 0.00011860614 [0.9876553] [0.02806257]
# 91 0.000112972106 [0.98795193] [0.02738793]
# 92 0.00010760728 [0.9882417] [0.02672957]
# 93 0.00010249508 [0.98852426] [0.02608699]
# 94 9.7625685e-05 [0.98880017] [0.02545988]
# 95 9.298887e-05 [0.9890694] [0.02484785]
# 96 8.857256e-05 [0.9893322] [0.02425053]
# 97 8.436466e-05 [0.9895886] [0.02366755]
# 98 8.035813e-05 [0.9898389] [0.02309859]
# 99 7.653994e-05 [0.9900831] [0.0225433]
#  test
# [4.972959]
